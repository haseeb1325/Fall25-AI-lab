# %%
def minimax(depth, node_index, is_maximizing_player, values, alpha, beta):
   
    if depth == 3:
        return values[node_index]
    
    if is_maximizing_player:
        best = -math.inf
       
        for i in range(2):
            val = minimax(depth + 1, node_index * 2 + i, False, values, alpha, beta)
            best = max(best, val)
            alpha = max(alpha, best)
           
            if beta <= alpha:
                break
        return best
    else:
        best = math.inf
      
        for i in range(2):
            val = minimax(depth + 1, node_index * 2 + i, True, values, alpha, beta)
            best = min(best, val)
            beta = min(beta, best)
           
            if beta <= alpha:
                break
        return best

if __name__ == "__main__":
   
    values = [3, 5, 6, 9, 1, 2, 0, -1]
    print("Values at leaf nodes:", values)
    
    optimal_value = minimax(0, 0, True, values, -math.inf, math.inf)
    print("The optimal value is:", optimal_value)
# Out:
# Values at leaf nodes: [3, 5, 6, 9, 1, 2, 0, -1]
# The optimal value is: 5
